# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_path = "data/laureates-1000.json"

# %%
with open(file_path, 'r') as file:
    data = json.load(file)

laureates = data['laureates']

# %%
laureates[:1]
# Out:
# [{'id': '745',
#   'knownName': {'en': 'A. Michael Spence', 'se': 'A. Michael Spence'},
#   'givenName': {'en': 'A. Michael', 'se': 'A. Michael'},
#   'familyName': {'en': 'Spence', 'se': 'Spence'},
#   'fullName': {'en': 'A. Michael Spence', 'se': 'A. Michael Spence'},
#   'fileName': 'spence',
#   'gender': 'male',
#   'birth': {'date': '1943-00-00',
#    'place': {'city': {'en': 'Montclair, NJ',
#      'no': 'Montclair, NJ',
#      'se': 'Montclair, NJ'},
#     'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#     'cityNow': {'en': 'Montclair, NJ',
#      'no': 'Montclair, NJ',
#      'se': 'Montclair, NJ',
#      'sameAs': ['https://www.wikidata.org/wiki/Q678437',
#       'https://www.wikipedia.org/wiki/Montclair,_New_Jersey'],
#      'latitude': '40.825930',
#      'longitude': '-74.209030'},
#     'countryNow': {'en': 'USA',
#      'no': 'USA',
#      'se': 'USA',
#      'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#      'latitude': '39.828175',
#      'longitude': '-98.579500'},
#     'continent': {'en': 'North America',
#      'no': 'Nord-Amerika',
#      'se': 'Nordamerika'},
#     'locationString': {'en': 'Montclair, NJ, USA',
#      'no': 'Montclair, NJ, USA',
#      'se': 'Montclair, NJ, USA'}}},
#   'wikipedia': {'slug': 'Michael_Spence',
#    'english': 'https://en.wikipedia.org/wiki/Michael_Spence'},
#   'wikidata': {'id': 'Q157245',
#    'url': 'https://www.wikidata.org/wiki/Q157245'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q157245',
#    'https://en.wikipedia.org/wiki/Michael_Spence'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/745',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/745',
#     'title': 'A. Michael Spence - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2001',
#     'category': {'en': 'Economic Sciences', 'no': 'Økonomi', 'se': 'Ekonomi'},
#     'categoryFullName': {'en': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel',
#      'no': 'Sveriges Riksbanks pris i økonomisk vitenskap til minne om Alfred Nobel',
#      'se': 'Sveriges Riksbanks pris i ekonomisk vetenskap till Alfred Nobels minne'},
#     'sortOrder': '2',
#     'portion': '1/3',
#     'dateAwarded': '2001-10-10',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for their analyses of markets with asymmetric information',
#      'se': 'för deras analys av marknader med assymetrisk informations'},
#     'prizeAmount': 10000000,
#     'prizeAmountAdjusted': 13927869,
#     'affiliations': [{'name': {'en': 'Stanford University',
#        'no': 'Stanford University',
#        'se': 'Stanford University'},
#       'nameNow': {'en': 'Stanford University'},
#       'city': {'en': 'Stanford, CA',
#        'no': 'Stanford, CA',
#        'se': 'Stanford, CA'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Stanford, CA',
#        'no': 'Stanford, CA',
#        'se': 'Stanford, CA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q173813',
#         'https://www.wikipedia.org/wiki/Stanford,_California'],
#        'latitude': '37.424734',
#        'longitude': '-122.163858'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Stanford, CA, USA',
#        'no': 'Stanford, CA, USA',
#        'se': 'Stanford, CA, USA'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/eco/2001',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/economic-sciences/2001/spence/facts/',
#       'title': 'A. Michael Spence - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/economic-sciences/2001/summary/',
#       'title': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel 2001',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]}]

# %%
# Extract birth dates and names
birth_data = []

for laureate in laureates:
    name = laureate.get('knownName', {}).get('en', '')
    birth_date = laureate.get('birth', {}).get('date')
    prizes = laureate.get('nobelPrizes', [])
    year = prizes[0].get('awardYear')
    category = prizes[0].get('category', {}).get('en', '')
    if birth_date:
        birth_data.append({'name': name, 'birth_date': birth_date, 'number-of-prizes': len(prizes), 'year': year, 'category': category})

# %%
birth_data[:5]
# Out:
# [{'name': 'A. Michael Spence',
#   'birth_date': '1943-00-00',
#   'number-of-prizes': 1,
#   'year': '2001',
#   'category': 'Economic Sciences'},
#  {'name': 'Aage N. Bohr',
#   'birth_date': '1922-06-19',
#   'number-of-prizes': 1,
#   'year': '1975',
#   'category': 'Physics'},
#  {'name': 'Aaron Ciechanover',
#   'birth_date': '1947-10-01',
#   'number-of-prizes': 1,
#   'year': '2004',
#   'category': 'Chemistry'},
#  {'name': 'Aaron Klug',
#   'birth_date': '1926-08-11',
#   'number-of-prizes': 1,
#   'year': '1982',
#   'category': 'Chemistry'},
#  {'name': 'Abdulrazak Gurnah',
#   'birth_date': '1948-00-00',
#   'number-of-prizes': 1,
#   'year': '2021',
#   'category': 'Literature'}]

# %%
# Convert to DataFrame
birth_df = pd.DataFrame(birth_data)

# %%
birth_df.head()
# Out:
#                 name  birth_date  number-of-prizes  year           category
# 0  A. Michael Spence  1943-00-00                 1  2001  Economic Sciences
# 1       Aage N. Bohr  1922-06-19                 1  1975            Physics
# 2  Aaron Ciechanover  1947-10-01                 1  2004          Chemistry
# 3         Aaron Klug  1926-08-11                 1  1982          Chemistry
# 4  Abdulrazak Gurnah  1948-00-00                 1  2021         Literature

# %%
# Work out which laureates share a birthday
# Find duplicate birth dates
duplicated_birth_dates = birth_df[birth_df.duplicated('birth_date', keep=False)].sort_values('birth_date')

# %%
duplicated_birth_dates.head()
# Out:
#                      name  birth_date  number-of-prizes  year    category
# 27           Albert Gobat  1843-05-21                 1  1902       Peace
# 571         Louis Renault  1843-05-21                 1  1907       Peace
# 716         Pieter Zeeman  1865-05-25                 1  1902     Physics
# 490          John R. Mott  1865-05-25                 1  1946       Peace
# 783  Roger Martin du Gard  1881-03-23                 1  1937  Literature

# %%
# Save the duplicated birth dates a CSV file
file_path = 'data/duplicated-birth-dates.csv'
duplicated_birth_dates.to_csv(file_path, index=False)

# %%
simple_combination = duplicated_birth_dates.groupby('birth_date').agg({'name': lambda x: ', '.join(x),    'number-of-prizes': 'sum',
    'year': list,
    'category': list}).reset_index()

# %%
simple_combination
# Out:
#     birth_date                                      name  number-of-prizes  \
# 0   1843-05-21               Albert Gobat, Louis Renault                 2
# 1   1865-05-25               Pieter Zeeman, John R. Mott                 2
# 2   1881-03-23  Roger Martin du Gard, Hermann Staudinger                 2
# 3   1895-10-30     Dickinson W. Richards, Gerhard Domagk                 2
# 4   1918-06-18           Jerome Karle, Franco Modigliani                 2
# 5   1930-03-15            Martin Karplus, Zhores Alferov                 2
# 6   1930-10-10               Harold Pinter, Yves Chauvin                 2
# 7   1932-10-24   Pierre-Gilles de Gennes, Robert Mundell                 2
# 8   1936-01-27         Samuel C.C. Ting, Barry C. Barish                 2
# 9   1938-03-07              David Baltimore, Albert Fert                 2
# 10  1940-01-04          Brian D. Josephson, Gao Xingjian                 2
# 11  1941-05-31     William D. Nordhaus, Louis J. Ignarro                 2
# 12  1941-07-01           Myron Scholes, Alfred G. Gilman                 2
# 13  1943-00-00             A. Michael Spence, Louis Brus                 2
# 14  1961-00-00            Dmitry Muratov, Moungi Bawendi                 2
#
#             year                                          category
# 0   [1902, 1907]                                    [Peace, Peace]
# 1   [1902, 1946]                                  [Physics, Peace]
# 2   [1937, 1953]                           [Literature, Chemistry]
# 3   [1956, 1939]  [Physiology or Medicine, Physiology or Medicine]
# 4   [1985, 1985]                    [Chemistry, Economic Sciences]
# 5   [2013, 2000]                              [Chemistry, Physics]
# 6   [2005, 2005]                           [Literature, Chemistry]
# 7   [1991, 1999]                      [Physics, Economic Sciences]
# 8   [1976, 2017]                                [Physics, Physics]
# 9   [1975, 2007]                 [Physiology or Medicine, Physics]
# 10  [1973, 2000]                             [Physics, Literature]
# 11  [2018, 1998]       [Economic Sciences, Physiology or Medicine]
# 12  [1997, 1994]       [Economic Sciences, Physiology or Medicine]
# 13  [2001, 2023]                    [Economic Sciences, Chemistry]
# 14  [2021, 2023]                                [Peace, Chemistry]

# %%
# Add a helper column to differentiate between the first and second winner
duplicated_birth_dates['winner'] = duplicated_birth_dates.groupby('birth_date').cumcount() + 1

# %%
duplicated_birth_dates.head()
# Out:
#                      name  birth_date  number-of-prizes  year    category  \
# 27           Albert Gobat  1843-05-21                 1  1902       Peace
# 571         Louis Renault  1843-05-21                 1  1907       Peace
# 716         Pieter Zeeman  1865-05-25                 1  1902     Physics
# 490          John R. Mott  1865-05-25                 1  1946       Peace
# 783  Roger Martin du Gard  1881-03-23                 1  1937  Literature
#
#      winner
# 27        1
# 571       2
# 716       1
# 490       2
# 783       1

# %%
# Pivot the table to separate each winner's details into different columns
pivoted_data = duplicated_birth_dates.pivot(index='birth_date', columns='winner', values=['name', 'year', 'category'])

# %%
pivoted_data.head()
# Out:
#                              name                      year        \
# winner                          1                   2     1     2
# birth_date
# 1843-05-21           Albert Gobat       Louis Renault  1902  1907
# 1865-05-25          Pieter Zeeman        John R. Mott  1902  1946
# 1881-03-23   Roger Martin du Gard  Hermann Staudinger  1937  1953
# 1895-10-30  Dickinson W. Richards      Gerhard Domagk  1956  1939
# 1918-06-18           Jerome Karle   Franco Modigliani  1985  1985
#
#                           category
# winner                           1                       2
# birth_date
# 1843-05-21                   Peace                   Peace
# 1865-05-25                 Physics                   Peace
# 1881-03-23              Literature               Chemistry
# 1895-10-30  Physiology or Medicine  Physiology or Medicine
# 1918-06-18               Chemistry       Economic Sciences

# %%
# Flatten the MultiIndex columns
pivoted_data.columns = [f'{col[0]}_{col[1]}' for col in pivoted_data.columns]

# %%
pivoted_data.head()
# Out:
#                            name_1              name_2 year_1 year_2  \
# birth_date
# 1843-05-21           Albert Gobat       Louis Renault   1902   1907
# 1865-05-25          Pieter Zeeman        John R. Mott   1902   1946
# 1881-03-23   Roger Martin du Gard  Hermann Staudinger   1937   1953
# 1895-10-30  Dickinson W. Richards      Gerhard Domagk   1956   1939
# 1918-06-18           Jerome Karle   Franco Modigliani   1985   1985
#
#                         category_1              category_2
# birth_date
# 1843-05-21                   Peace                   Peace
# 1865-05-25                 Physics                   Peace
# 1881-03-23              Literature               Chemistry
# 1895-10-30  Physiology or Medicine  Physiology or Medicine
# 1918-06-18               Chemistry       Economic Sciences

# %%
# Reset the index to have 'birth_date' as a column
pivoted_data = pivoted_data.reset_index()

# %%
pivoted_data
# Out:
#     birth_date                   name_1              name_2 year_1 year_2  \
# 0   1843-05-21             Albert Gobat       Louis Renault   1902   1907
# 1   1865-05-25            Pieter Zeeman        John R. Mott   1902   1946
# 2   1881-03-23     Roger Martin du Gard  Hermann Staudinger   1937   1953
# 3   1895-10-30    Dickinson W. Richards      Gerhard Domagk   1956   1939
# 4   1918-06-18             Jerome Karle   Franco Modigliani   1985   1985
# 5   1930-03-15           Martin Karplus      Zhores Alferov   2013   2000
# 6   1930-10-10            Harold Pinter        Yves Chauvin   2005   2005
# 7   1932-10-24  Pierre-Gilles de Gennes      Robert Mundell   1991   1999
# 8   1936-01-27         Samuel C.C. Ting     Barry C. Barish   1976   2017
# 9   1938-03-07          David Baltimore         Albert Fert   1975   2007
# 10  1940-01-04       Brian D. Josephson        Gao Xingjian   1973   2000
# 11  1941-05-31      William D. Nordhaus    Louis J. Ignarro   2018   1998
# 12  1941-07-01            Myron Scholes    Alfred G. Gilman   1997   1994
# 13  1943-00-00        A. Michael Spence          Louis Brus   2001   2023
# 14  1961-00-00           Dmitry Muratov      Moungi Bawendi   2021   2023
#
#                 category_1              category_2
# 0                    Peace                   Peace
# 1                  Physics                   Peace
# 2               Literature               Chemistry
# 3   Physiology or Medicine  Physiology or Medicine
# 4                Chemistry       Economic Sciences
# 5                Chemistry                 Physics
# 6               Literature               Chemistry
# 7                  Physics       Economic Sciences
# 8                  Physics                 Physics
# 9   Physiology or Medicine                 Physics
# 10                 Physics              Literature
# 11       Economic Sciences  Physiology or Medicine
# 12       Economic Sciences  Physiology or Medicine
# 13       Economic Sciences               Chemistry
# 14                   Peace               Chemistry

# %%
# Save the duplicated birth dates a CSV file
file_path = 'data/duplicated-birth-dates-2.csv'
pivoted_data.to_csv(file_path, index=False)
